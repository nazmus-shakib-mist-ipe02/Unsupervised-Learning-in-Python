# %% [markdown]
# In the video, you saw a hierarchical clustering of the voting countries at the Eurovision song contest using 'complete' linkage. Now, perform a hierarchical clustering of the voting countries with 'single' linkage, and compare the resulting dendrogram with the one in the video. Different linkage, different hierarchical clustering!
#
# You are given an array samples. Each row corresponds to a voting country, and each column corresponds to a performance that was voted for. The list country_names gives the name of each voting country. This dataset was obtained from Eurovision.
#
# Instructions
#
# * Import:
# * linkage and dendrogram from scipy.cluster.hierarchy.
# * matplotlib.pyplot as plt.
# * Perform hierarchical clustering on samples using the linkage() function with the method='single' keyword argument. Assign the result to mergings.
# * Plot a dendrogram of the hierarchical clustering, using the list country_names as the labels. In addition, specify the * leaf_rotation=90, and leaf_font_size=6 keyword arguments as you have done earlier.

# %%
import pandas as pd
df=pd.read_csv('eurovision-2016.csv')
df.head()
# Out:
#   From country       To country  Jury A  Jury B  Jury C  Jury D  Jury E  \
# 0      Albania          Belgium      20      16      24      22      24
# 1      Albania   Czech Republic      21      15      25      23      16
# 2      Albania  The Netherlands      22      14      23      24      21
# 3      Albania       Azerbaijan      19      12      11      21      11
# 4      Albania          Hungary       8      13       9      14       9
#
#    Jury Rank  Televote Rank  Jury Points  Televote Points
# 0         25             14          NaN              NaN
# 1         22             22          NaN              NaN
# 2         24             24          NaN              NaN
# 3         13             19          NaN              NaN
# 4         10             10          1.0              1.0

# %%
df=df.fillna(0)
df.head()
# Out:
#   From country       To country  Jury A  Jury B  Jury C  Jury D  Jury E  \
# 0      Albania          Belgium      20      16      24      22      24
# 1      Albania   Czech Republic      21      15      25      23      16
# 2      Albania  The Netherlands      22      14      23      24      21
# 3      Albania       Azerbaijan      19      12      11      21      11
# 4      Albania          Hungary       8      13       9      14       9
#
#    Jury Rank  Televote Rank  Jury Points  Televote Points
# 0         25             14          0.0              0.0
# 1         22             22          0.0              0.0
# 2         24             24          0.0              0.0
# 3         13             19          0.0              0.0
# 4         10             10          1.0              1.0

# %%
sample=df.drop(['From country','To country'], axis=1).to_numpy()
#sample.head()
#sample.info()
sample
# Out:
# array([[20., 16., 24., ..., 14.,  0.,  0.],
#        [21., 15., 25., ..., 22.,  0.,  0.],
#        [22., 14., 23., ..., 24.,  0.,  0.],
#        ...,
#        [ 2.,  2.,  3., ..., 19., 12.,  0.],
#        [23., 15., 12., ..., 13.,  0.,  0.],
#        [15., 22.,  7., ..., 18.,  0.,  0.]])

# %%
country_name=df['From country']

# %%
# Perform the necessary imports
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram

# Calculate the linkage: mergings
mergings = linkage(sample, method='single')

# Plot the dendrogram
dendrogram(mergings, labels=country_name, leaf_rotation=90, leaf_font_size=6)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-bb72474f3d4d> in <module>()
#       7
#       8 # Plot the dendrogram
# ----> 9 dendrogram(mergings, labels=country_name, leaf_rotation=90, leaf_font_size=6)
#      10 plt.show()
#
# ~\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in dendrogram(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, no_plot, no_labels, leaf_font_size, leaf_rotation, leaf_label_func, show_contracted, link_color_func, ax, above_threshold_color)
#    2499         contraction_marks=contraction_marks,
#    2500         link_color_func=link_color_func,
# -> 2501         above_threshold_color=above_threshold_color)
#    2502
#    2503     if not no_plot:
#
# ~\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in _dendrogram_calculate_info(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, i, iv, ivl, n, icoord_list, dcoord_list, lvs, mhr, current_color, color_list, currently_below_threshold, leaf_label_func, level, contraction_marks, link_color_func, above_threshold_color)
#    2752             level=level + 1, contraction_marks=contraction_marks,
#    2753             link_color_func=link_color_func,
# -> 2754             above_threshold_color=above_threshold_color)
#    2755
#    2756     h = Z[i - n, 2]
#
# ~\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in _dendrogram_calculate_info(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, i, iv, ivl, n, icoord_list, dcoord_list, lvs, mhr, current_color, color_list, currently_below_threshold, leaf_label_func, level, contraction_marks, link_color_func, above_threshold_color)
#    2664     if i < n:
#    2665         _append_singleton_leaf_node(Z, p, n, level, lvs, ivl,
# -> 2666                                     leaf_label_func, i, labels)
#    2667         return (iv + 5.0, 10.0, 0.0, 0.0)
#    2668
#
# ~\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in _append_singleton_leaf_node(Z, p, n, level, lvs, ivl, leaf_label_func, i, labels)
#    2534             # for the leaf nodes, use it.
#    2535             if labels is not None:
# -> 2536                 ivl.append(labels[int(i - n)])
#    2537             else:
#    2538                 # Otherwise, use the id as the label for the leaf.x
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -536
